# %% [markdown]
# #**Deep Learning Homework 5: *Autoencoders***
# ### MSc Computer Science, Data Science, Cybersecurity Computer Engeneering @UniPD
# ### 2nd semester - 6 ECTS
# ### Prof. Nicolò Navarin & Prof. Alessandro Sperduti
# ---
#
#
# In this homework, we will deal with _dimensionality reduction_ and learn how to develop a simple _Autoencoder_.
# In the first part, we will learn how to develop a simple shallow autoencoder, then we will develop a deep version. Next, we will experiment with the application of autoencoder on denoising data task (denoising-autoencoder). Finally, we will apply this model to sequential domains, considering the IMDB dataset seen in HW4.

# %%
# import the usual libriaries
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

np.random.seed(42)

# %% [markdown]
# ### Load Dataset
# We load the CIFAR-10 dataset, using `tf.keras.datasets`. The dataset contains 60,000 training images and 10,000 testing images.
# The images are originally in RGB format, but we will convert them to grayscale for convenience. The value of each pixel is between 0 and 255, and it represents a point of an image of size 32 x 32. We will normalize all values between 0 and 1, and we will flatten the 32x32 images into vectors of size 1024.
# Finally, since no validation set is defined, we split the test set in a validation set and a new test set.

# %%
cifar_10 = keras.datasets.cifar10
(X_train_full, _), (x_test, _) = cifar_10.load_data() # The dataset is already divede in test and training

X_train_full, x_test = np.mean(X_train_full, -1), np.mean(x_test, -1)

X_train_full = X_train_full.astype('float32') / 255
x_test = x_test.astype('float32') / 255

X_train_full = X_train_full.reshape((len(X_train_full), np.prod(X_train_full.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# We extract the first 10000 samples of the training set, to use them as the validation set
x_valid, x_train = X_train_full[:10000], X_train_full[10000:]
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# 170508288/170498071 [==============================] - 2s 0us/step

# %% [markdown]
# ## [TO COMPLETE] Exercise 5.1: Singular Value Decomposition
#
# Similar to Principal component analysis (PCA), Singular Value Decomposition (SVD) is a standard linear dimensionality reduction method. They both linealry combine the features of the original high-dimensional dataset and project them into a lower-dimensional space, ideally retaing most of thier intrinsic properties.
#
# In this first part of the HW, we will focus our attention on SVD decomposition and its performances. Given a matrix $X$, the SVD decomposes it into the product of two unitary matrices $V$ and $U$ and a rectangular diagonal matrix of singular values $S$:
#
# $$ X=V \cdot S \cdot U^T.$$
#
# The SVD is already implemented in NumPy as `np.linalg.svd`. In our case, the $X$ matrix will represent the training set, where each row is a sample (therefore the number of columns will be the number of input features). However, notice that the $X$ matrix has a huge number of rows (we have 50,000 input samples) and only 784 columns. If you are using the _Colab_ free plan, the quantity of available RAM may not be sufficient to compute the SVD of $X$. Therefore, to ease memory consumption and numerical stability, we resort to one property of the SVD and compute its equivalent version from the covariance matrix $C= X^T \cdot X$, that can be decomposed as:
#
# $$ C= U \cdot S^2 \cdot U^T$$
#
# Since we need just the matrix $U$ to compute the compressed version of our data, this trick turns out to be a quick and good solution.

# %%
def SVD(X, k):
  # Compute covariance matrix
  C = np.dot(X.T, X)
  # SVD decomposition
  U, s_sqr, U_T = np.linalg.svd(C, full_matrices=False)
  # Limit the number columns of U to k
  U_k=U[:,:k]
  return U_k

# %% [markdown]
# Let's define the `ENCODING_DIM`, that will be the size of the compressed version of input data, and project the low-dimensional versions of the training set and the test set as well.

# %%
ENCODING_DIM = 256

U_k = SVD(x_train, ENCODING_DIM)

x_training_svd = np.dot(x_train, U_k)
x_test_svd = np.dot(x_test, U_k)

# %% [markdown]
# We now reconstruct back the original input and check how much information was lost due to the compression. We do so by computing the mean squared error between the original input and the reconstruction, and by plotting the reconstructed images.

# %%
x_training_reco = np.dot(x_training_svd, U_k.T)
x_test_reco = np.dot(x_test_svd, U_k.T)

# %%
accuracy_train = ((x_train - x_training_reco)**2).mean()
accuracy_test = ((x_test - x_test_reco)**2).mean()

print("Training mse: %.5f" % ( accuracy_train))
print("Test mse: %.5f" % ( accuracy_test))
# Out:
# Training mse: 0.00150
# Test mse: 0.00153

# %%
def plot_img(n, images_sets: list, title=""):
  plt.figure(figsize=(20, 4))
  for i in range(n):
    for set_idx, images in enumerate(images_sets):
      ax = plt.subplot(len(images_sets), n, i + 1 + set_idx*n)
      plt.imshow(images[i].reshape(32, 32))
      plt.gray()
      ax.get_xaxis().set_visible(False)
      ax.get_yaxis().set_visible(False)
  plt.suptitle(title)
  plt.show()

# %% [markdown]
# Let's see how well the input can be reconstructed by displaying a few of the input images and the corresponding reconstructions. Obviously, all these evaluations have to be done on the test set.
#
# The first row of images corresponds to input data, while the second one contains the reconstructions.

# %%
plot_img(10, [x_test, x_test_reco], title = "Original (top) vs Reconstructed (bottom)")

# %% [markdown]
# **[TO COMPLETE]**: What happens by varying the `ENCODING_DIM`? Try it out and discuss the results in this cell.
#
# _Answer:_ Obviously, the higher the encoding dimension, the more informations we can store about the input data.
#
# | ENCODING_DIM | test MSE |
# |------------:|---------:|
# |50|0.00750|
# |120|0.00375|
# |256|0.00153|
# |700|0.00005|

# %% [markdown]
# ## [TO COMPLETE] Exercise 5.2: Shallow Linear Autoencoder
# Let's define a model that consists of a single fully-connected neural layer. The hidden layer and the output layer act as the encoder and the decoder, respectively. Differently than the previous HW when we used `Keras.Sequential()`, here we define the two parts of the model (encoder and decoder) separately and then we create the final model.

# %%
ENCODING_DIM = 256
INPUT_DIM = x_train.shape[-1]

input_img = tf.keras.layers.Input(shape=(INPUT_DIM,))
# Define the encoder...
encoded = tf.keras.layers.Dense(ENCODING_DIM, activation='linear')(input_img)

# ...the decoder...
decoded = tf.keras.layers.Dense(INPUT_DIM, activation='linear')(encoded)

# and the autoencoder
autoencoder = tf.keras.models.Model(input_img, decoded)

# In order to visualize the learned encoding, define a model that computes the 
# two parts separately.
encoder = tf.keras.models.Model(input_img, encoded)
encoded_input = tf.keras.layers.Input(shape=(ENCODING_DIM,))
decoder_layer = autoencoder.layers[-1]
decoder = tf.keras.models.Model(encoded_input, decoder_layer(encoded_input))

# Finally, let's call the compile method
autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.005), loss='mse')

# %% [markdown]
# Print the model summary.

# %%
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 1024)]            0
#
#  dense (Dense)               (None, 256)               262400
#
#  dense_1 (Dense)             (None, 1024)              263168
#
# =================================================================
# Total params: 525,568
# Trainable params: 525,568
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Train the model.

# %%
history = autoencoder.fit(x_train, x_train, epochs=15, batch_size=512, shuffle=True, validation_data=(x_valid, x_valid))
# Out:
# Epoch 1/15
# 79/79 [==============================] - 3s 9ms/step - loss: 0.1856 - val_loss: 0.0307
# Epoch 2/15
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0601 - val_loss: 0.0213
# Epoch 3/15
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0187 - val_loss: 0.0168
# Epoch 4/15
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0153 - val_loss: 0.0141
# Epoch 5/15
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0130 - val_loss: 0.0122
# Epoch 6/15
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0114 - val_loss: 0.0108
# Epoch 7/15
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0101 - val_loss: 0.0097
# Epoch 8/15
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0091 - val_loss: 0.0088
# Epoch 9/15
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0086 - val_loss: 0.0089
# Epoch 10/15
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0078 - val_loss: 0.0075
# Epoch 11/15
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0074 - val_loss: 0.0070
# Epoch 12/15
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0068 - val_loss: 0.0067
# Epoch 13/15
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0063 - val_loss: 0.0061
# Epoch 14/15
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0059 - val_loss: 0.0059
# Epoch 15/15
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0058 - val_loss: 0.0055

# %% [markdown]
# Plot the loss and the accuracy curves on the validation set, and the accuracy on the test set.

# %%
def plot_loss(history):
  plt.figure(figsize=(10,6))
  plt.plot(history.epoch,history.history['loss'])
  plt.plot(history.epoch,history.history['val_loss'])
  plt.grid()
  plt.title('loss')

# %%
plot_loss(history)

scores = autoencoder.evaluate(x_test, x_test, verbose=2)
print("Test mse: %.5f" % (scores))
# Out:
# 313/313 - 0s - loss: 0.0055 - 473ms/epoch - 2ms/step
# Test mse: 0.00545

# %%
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

plot_img(10, [x_test, decoded_imgs], title = "Original (top) vs Reconstructed (bottom)")

# %% [markdown]
# **[TO COMPLETE]** Check the results and compare them versus the results obtained with the SVD. Give an explanation of the relation between the results obtained  by the shallow linear autoencoder and the ones obtained by the SVD decomposition.
#
#
# _Answer:_
# As we can see from the table below, the shallow linear autoencoder, which is a probabilistic method, has slightly worse performance, maybe because 256 units for the encoder (hidden layer) isn't enough when dealing with this kind of images.
#
# | Model (ENCODING_DIM=256) | test MSE |
# |:------------:|:---------:|
# |Shallow Linear Autoencoder|0.00568|
# |SVD|0.00153|

# %% [markdown]
# ##[TO COMPLETE] Exercise 5.3: Shallow Non-linear Autoencoders
#
# **[TO COMPLETE]** Replicate the code of Exercise 5.2 but in this case, instead of using linear activation functions use non-linear ones. Choose the most appropriate non-linear function, and motivate your choice. Then discuss the results in relation to those obtained in Exercise 5.2.
#
# Insert your code and theoretical discussion into cells immediately below this one.

# %%
ENCODING_DIM = 256
INPUT_DIM = x_train.shape[-1]

input_img = tf.keras.layers.Input(shape=(INPUT_DIM,))
# Define the encoder...
encoded = tf.keras.layers.Dense(ENCODING_DIM, activation='sigmoid')(input_img)

# ...the decoder...
decoded = tf.keras.layers.Dense(INPUT_DIM, activation='sigmoid')(encoded)

# and the autoencoder
autoencoder = tf.keras.models.Model(input_img, decoded)

# In order to visualize the learned encoding, define a model that computes the 
# two parts separately.
encoder = tf.keras.models.Model(input_img, encoded)
encoded_input = tf.keras.layers.Input(shape=(ENCODING_DIM,))
decoder_layer = autoencoder.layers[-1]
decoder = tf.keras.models.Model(encoded_input, decoder_layer(encoded_input))

# Finally, let's call the compile method
autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.005), loss='mse')

history = autoencoder.fit(x_train, x_train, epochs=15, batch_size=512, shuffle=True, validation_data=(x_valid, x_valid))
# Out:
# Epoch 1/15
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0355 - val_loss: 0.0239
# Epoch 2/15
# 79/79 [==============================] - 3s 37ms/step - loss: 0.0199 - val_loss: 0.0196
# Epoch 3/15
# 79/79 [==============================] - 3s 36ms/step - loss: 0.0152 - val_loss: 0.0136
# Epoch 4/15
# 79/79 [==============================] - 3s 38ms/step - loss: 0.0130 - val_loss: 0.0165
# Epoch 5/15
# 79/79 [==============================] - 3s 38ms/step - loss: 0.0126 - val_loss: 0.0124
# Epoch 6/15
# 79/79 [==============================] - 3s 38ms/step - loss: 0.0105 - val_loss: 0.0101
# Epoch 7/15
# 79/79 [==============================] - 3s 37ms/step - loss: 0.0115 - val_loss: 0.0155
# Epoch 8/15
# 79/79 [==============================] - 3s 37ms/step - loss: 0.0102 - val_loss: 0.0093
# Epoch 9/15
# 79/79 [==============================] - 3s 36ms/step - loss: 0.0086 - val_loss: 0.0084
# Epoch 10/15
# 79/79 [==============================] - 3s 37ms/step - loss: 0.0082 - val_loss: 0.0081
# Epoch 11/15
# 79/79 [==============================] - 3s 36ms/step - loss: 0.0080 - val_loss: 0.0075
# Epoch 12/15
# 79/79 [==============================] - 3s 37ms/step - loss: 0.0078 - val_loss: 0.0076
# Epoch 13/15
# 79/79 [==============================] - 3s 37ms/step - loss: 0.0074 - val_loss: 0.0072
# Epoch 14/15
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0083 - val_loss: 0.0075
# Epoch 15/15
# 79/79 [==============================] - 3s 35ms/step - loss: 0.0067 - val_loss: 0.0065

# %%
plot_loss(history)

scores = autoencoder.evaluate(x_test, x_test, verbose=2)
print("Test mse: %.5f" % (scores))
# Out:
# 313/313 - 1s - loss: 0.0065 - 772ms/epoch - 2ms/step
# Test mse: 0.00647

# %%
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

plot_img(10, [x_test, decoded_imgs], title = "Original (top) vs Reconstructed (bottom)")

# %% [markdown]
# _Answer:_
#
# | Model (ENCODING_DIM=256) | test MSE |
# |:------------:|:---------:|
# |Shallow Linear Autoencoder|0.00568|
# |SVD|0.00153|
# |Shallow Non-linear Autoencoder|0.00647|
#
# I tried several non-linear activations function (tanh, softplus, sigmoid), and I found out that 'sigmoid' gives the best performance. The performance of non-linear autoencoder decreases with respect to the previous 2 models maybe because the non-linearity is not exploited with a shallow autoencoder with only 256 encoding units for this kind of input (images).

# %% [markdown]
# ##[TO COMPLETE] Exercise 5.4: Deep Autoencoder
# **[TO COMPLETE]** Build a deep version of the Autoencoder defined above. The autoencoder has to use at least 5 layers. The model will use $n$ layers for encoding, and $n-1$ for decoding. The layers sizes of the encoding part decrease at each layer (e.g., `INPUT_DIM->128->64`, where 64 is the encoding dim). The decoding part layers dimensions progression turns out to be mirrored (e.g., `128->INPUT_DIM`, the final overall structure recalls an hourglass ⏳).
# As usual, print the model summary, the loss curves during the training, the achieved loss on the test set, and some input images with the corresponding decoding.

# %%
INPUT_DIM = x_train.shape[-1]

input_img = tf.keras.layers.Input(shape=(INPUT_DIM,))
#encoding layers
encoded1 = tf.keras.layers.Dense(512, activation='sigmoid')(input_img)
encoded2 = tf.keras.layers.Dense(256, activation='tanh')(encoded1)
#decoding layers
decoded1 = tf.keras.layers.Dense(512, activation='tanh')(encoded2)
decoded2 = tf.keras.layers.Dense(INPUT_DIM, activation='sigmoid')(decoded1)

autoencoder = tf.keras.models.Model(input_img, decoded2) 

autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005), loss='mse')

# %%
autoencoder.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 1024)]            0
#
#  dense_24 (Dense)            (None, 512)               524800
#
#  dense_25 (Dense)            (None, 256)               131328
#
#  dense_26 (Dense)            (None, 512)               131584
#
#  dense_27 (Dense)            (None, 1024)              525312
#
# =================================================================
# Total params: 1,313,024
# Trainable params: 1,313,024
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = autoencoder.fit(x_train, x_train, epochs = 80, batch_size = 512, shuffle=True, validation_data=(x_valid, x_valid))
# Out:
# Epoch 1/80
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0337 - val_loss: 0.0230
# Epoch 2/80
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0192 - val_loss: 0.0176
# Epoch 3/80
# 79/79 [==============================] - 1s 6ms/step - loss: 0.0158 - val_loss: 0.0147
# Epoch 4/80
# 79/79 [==============================] - 1s 6ms/step - loss: 0.0138 - val_loss: 0.0131
# Epoch 5/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0123 - val_loss: 0.0117
# Epoch 6/80
# 79/79 [==============================] - 1s 6ms/step - loss: 0.0112 - val_loss: 0.0108
# Epoch 7/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0104 - val_loss: 0.0101
# Epoch 8/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0098 - val_loss: 0.0097
# Epoch 9/80
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0091 - val_loss: 0.0091
# Epoch 10/80
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0087 - val_loss: 0.0085
# Epoch 11/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0082 - val_loss: 0.0081
# Epoch 12/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0079 - val_loss: 0.0083
# Epoch 13/80
# 79/79 [==============================] - 1s 6ms/step - loss: 0.0076 - val_loss: 0.0075
# Epoch 14/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0073 - val_loss: 0.0073
# Epoch 15/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0070 - val_loss: 0.0070
# Epoch 16/80
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0068 - val_loss: 0.0068
# Epoch 17/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0066 - val_loss: 0.0065
# Epoch 18/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0064 - val_loss: 0.0065
# Epoch 19/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0062 - val_loss: 0.0062
# Epoch 20/80
# 79/79 [==============================] - 1s 6ms/step - loss: 0.0061 - val_loss: 0.0063
# Epoch 21/80
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0059 - val_loss: 0.0061
# Epoch 22/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0058 - val_loss: 0.0058
# Epoch 23/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0056 - val_loss: 0.0057
# Epoch 24/80
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0055 - val_loss: 0.0055
# Epoch 25/80
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0054 - val_loss: 0.0053
# Epoch 26/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0053 - val_loss: 0.0053
# Epoch 27/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0053 - val_loss: 0.0052
# Epoch 28/80
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0050 - val_loss: 0.0052
# Epoch 29/80
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0050 - val_loss: 0.0051
# Epoch 30/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0049 - val_loss: 0.0051
# Epoch 31/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0048 - val_loss: 0.0049
# Epoch 32/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0047 - val_loss: 0.0048
# Epoch 33/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0047 - val_loss: 0.0047
# Epoch 34/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0046 - val_loss: 0.0046
# Epoch 35/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0045 - val_loss: 0.0046
# Epoch 36/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0045 - val_loss: 0.0046
# Epoch 37/80
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0044 - val_loss: 0.0047
# Epoch 38/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0044
# Epoch 39/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0044
# Epoch 40/80
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0042 - val_loss: 0.0043
# Epoch 41/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0042 - val_loss: 0.0043
# Epoch 42/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0042
# Epoch 43/80
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 44/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0041 - val_loss: 0.0043
# Epoch 45/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 46/80
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 47/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 48/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 49/80
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 50/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 51/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 52/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0037 - val_loss: 0.0040
# Epoch 53/80
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 54/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0039 - val_loss: 0.0037
# Epoch 55/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 56/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 57/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0036 - val_loss: 0.0039
# Epoch 58/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0036 - val_loss: 0.0038
# Epoch 59/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0036 - val_loss: 0.0036
# Epoch 60/80
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0035 - val_loss: 0.0036
# Epoch 61/80
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0035 - val_loss: 0.0036
# Epoch 62/80
# 79/79 [==============================] - 1s 6ms/step - loss: 0.0035 - val_loss: 0.0036
# Epoch 63/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0034 - val_loss: 0.0035
# Epoch 64/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0034 - val_loss: 0.0035
# Epoch 65/80
# 79/79 [==============================] - 1s 6ms/step - loss: 0.0034 - val_loss: 0.0037
# Epoch 66/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0034 - val_loss: 0.0035
# Epoch 67/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0033 - val_loss: 0.0034
# Epoch 68/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0033 - val_loss: 0.0034
# Epoch 69/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 70/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 71/80
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0033 - val_loss: 0.0034
# Epoch 72/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0033 - val_loss: 0.0033
# Epoch 73/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0032 - val_loss: 0.0033
# Epoch 74/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0033 - val_loss: 0.0038
# Epoch 75/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 76/80
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0032 - val_loss: 0.0033
# Epoch 77/80
# 79/79 [==============================] - 1s 6ms/step - loss: 0.0032 - val_loss: 0.0033
# Epoch 78/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0031 - val_loss: 0.0033
# Epoch 79/80
# 79/79 [==============================] - 1s 6ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 80/80
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0031 - val_loss: 0.0031

# %%
plot_loss(history)

scores = autoencoder.evaluate(x_test, x_test, verbose=2)
print("test mse: %.5f" % (scores))
# Out:
# 313/313 - 1s - loss: 0.0031 - 511ms/epoch - 2ms/step
# test mse: 0.00311

# %%
decoded_imgs = autoencoder.predict(x_test)

plot_img(10, [x_test, decoded_imgs], title = "Original (top) vs Reconstructed (bottom)")

# %% [markdown]
# ## [TO COMPLETE] Exercise 5.5: Denoising Autoencoder
#
# Let's now use a shallow autoencoder to denoise the input data. The idea is that only meaningful information will be encoded, thus filtering out useless noise.
# Firstly, define a noisy input by adding some gaussian noise to our input data. We define a noise factor that can be used to modify the amount of noise to add to the input data. Check how much it influences the denoising capability of the autoencoder.

# %%
noise_factor = 0.3

x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)
x_valid_noisy = x_valid + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_valid.shape)

# we still have to be sure that the color values are in the [0,1] range:
x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)
x_valid_noisy = np.clip(x_valid_noisy, 0., 1.)

# %% [markdown]
# Plot some noisy inputs:

# %%
plot_img(10, [x_test_noisy, x_test], title = "Noisy (top) vs Original (bottom)")

# %% [markdown]
# **[TO COMPLETE]** Define a shallow autoencoder able to compute a de-noised version of the input (use a noise_factor $\geq 0.3$).

# %%
INPUT_DIM = x_train.shape[-1]
ENCODING_DIM = 256

input_img = tf.keras.layers.Input(shape=(INPUT_DIM,))
# encoder
encoded = tf.keras.layers.Dense(ENCODING_DIM, activation='tanh')(input_img)
# decoder
decoded = tf.keras.layers.Dense(INPUT_DIM, activation='sigmoid')(encoded)

autoencoder = tf.keras.models.Model(input_img, decoded)

autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005), loss='mse') #[TO COMPLETE]

# %%
autoencoder.summary()
# Out:
# Model: "model_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_14 (InputLayer)       [(None, 1024)]            0
#
#  dense_40 (Dense)            (None, 256)               262400
#
#  dense_41 (Dense)            (None, 1024)              263168
#
# =================================================================
# Total params: 525,568
# Trainable params: 525,568
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **[TO COMPLETE]** Train the model by passing the noisy input and the clean target.

# %%
history = autoencoder.fit(x_train_noisy, x_train, epochs=60, batch_size=512, shuffle=True, validation_data=(x_valid_noisy, x_valid)) #[TO COMPLETE]
# Out:
# Epoch 1/60
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0100 - val_loss: 0.0108
# Epoch 2/60
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0101 - val_loss: 0.0107
# Epoch 3/60
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0100 - val_loss: 0.0105
# Epoch 4/60
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0100 - val_loss: 0.0105
# Epoch 5/60
# 79/79 [==============================] - 1s 6ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 6/60
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0100 - val_loss: 0.0110
# Epoch 7/60
# 79/79 [==============================] - 1s 6ms/step - loss: 0.0100 - val_loss: 0.0104
# Epoch 8/60
# 79/79 [==============================] - 1s 6ms/step - loss: 0.0100 - val_loss: 0.0108
# Epoch 9/60
# 79/79 [==============================] - 1s 6ms/step - loss: 0.0100 - val_loss: 0.0105
# Epoch 10/60
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0100 - val_loss: 0.0105
# Epoch 11/60
# 79/79 [==============================] - 1s 6ms/step - loss: 0.0100 - val_loss: 0.0106
# Epoch 12/60
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0100 - val_loss: 0.0104
# Epoch 13/60
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0100 - val_loss: 0.0109
# Epoch 14/60
# 79/79 [==============================] - 1s 6ms/step - loss: 0.0100 - val_loss: 0.0105
# Epoch 15/60
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0099 - val_loss: 0.0106
# Epoch 16/60
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0099 - val_loss: 0.0105
# Epoch 17/60
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0099 - val_loss: 0.0108
# Epoch 18/60
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0099 - val_loss: 0.0104
# Epoch 19/60
# 79/79 [==============================] - 1s 6ms/step - loss: 0.0099 - val_loss: 0.0107
# Epoch 20/60
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0099 - val_loss: 0.0104
# Epoch 21/60
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0099 - val_loss: 0.0104
# Epoch 22/60
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0099 - val_loss: 0.0104
# Epoch 23/60
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0100 - val_loss: 0.0105
# Epoch 24/60
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0099 - val_loss: 0.0105
# Epoch 25/60
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0099 - val_loss: 0.0104
# Epoch 26/60
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0098 - val_loss: 0.0105
# Epoch 27/60
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0099 - val_loss: 0.0105
# Epoch 28/60
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0099 - val_loss: 0.0105
# Epoch 29/60
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0099 - val_loss: 0.0104
# Epoch 30/60
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0099 - val_loss: 0.0104
# Epoch 31/60
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0098 - val_loss: 0.0104
# Epoch 32/60
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0099 - val_loss: 0.0104
# Epoch 33/60
# 79/79 [==============================] - 1s 6ms/step - loss: 0.0098 - val_loss: 0.0104
# Epoch 34/60
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0099 - val_loss: 0.0105
# Epoch 35/60
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0099 - val_loss: 0.0105
# Epoch 36/60
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0099 - val_loss: 0.0105
# Epoch 37/60
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0099 - val_loss: 0.0104
# Epoch 38/60
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0098 - val_loss: 0.0104
# Epoch 39/60
# 79/79 [==============================] - 1s 6ms/step - loss: 0.0099 - val_loss: 0.0103
# Epoch 40/60
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0098 - val_loss: 0.0104
# Epoch 41/60
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0098 - val_loss: 0.0104
# Epoch 42/60
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0098 - val_loss: 0.0104
# Epoch 43/60
# 79/79 [==============================] - 1s 6ms/step - loss: 0.0099 - val_loss: 0.0106
# Epoch 44/60
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0098 - val_loss: 0.0103
# Epoch 45/60
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0098 - val_loss: 0.0104
# Epoch 46/60
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0098 - val_loss: 0.0103
# Epoch 47/60
# 79/79 [==============================] - 1s 6ms/step - loss: 0.0099 - val_loss: 0.0106
# Epoch 48/60
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0098 - val_loss: 0.0106
# Epoch 49/60
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0098 - val_loss: 0.0103
# Epoch 50/60
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0098 - val_loss: 0.0103
# Epoch 51/60
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0098 - val_loss: 0.0103
# Epoch 52/60
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0098 - val_loss: 0.0107
# Epoch 53/60
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0098 - val_loss: 0.0104
# Epoch 54/60
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0098 - val_loss: 0.0107
# Epoch 55/60
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0098 - val_loss: 0.0104
# Epoch 56/60
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0098 - val_loss: 0.0103
# Epoch 57/60
# 79/79 [==============================] - 1s 6ms/step - loss: 0.0098 - val_loss: 0.0104
# Epoch 58/60
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0098 - val_loss: 0.0103
# Epoch 59/60
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0098 - val_loss: 0.0104
# Epoch 60/60
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0098 - val_loss: 0.0103

# %%
plot_loss(history)

scores = autoencoder.evaluate(x_test_noisy, x_test, verbose=2)
print("Test mse: %.5f" % (scores))
# Out:
# 313/313 - 0s - loss: 0.0103 - 475ms/epoch - 2ms/step
# Test mse: 0.01031

# %% [markdown]
# **[TO COMPLETE]** Check the result by plotting some input images and the corresponding denoised outputs.

# %%
decoded_imgs = autoencoder.predict(x_test_noisy)

plot_img(10, [x_test_noisy, x_test, decoded_imgs])

# %% [markdown]
# ## Exercise 5.6: Linear Autoencoder for sequences
#
# Let's define a linear autoencoder for sequences. In this case we will use the IMDB dataset (already introduced in HW4). To have a model that can be trained and tested in a reasonable time (and that works also with the memory limitation that we have in _Colab_), we will limit the number of training samples and test samples.

# %%
num_words = 100
(X_train, _), (X_test, _) = keras.datasets.imdb.load_data(num_words=num_words)

X_train=X_train[:10000]

(X_valid, X_test) = X_test[:1250], X_test[-1250:]

word_index = keras.datasets.imdb.get_word_index()

reverse_index = {word_id + 3: word for word, word_id in word_index.items()}
reverse_index[0] = "<pad>" # padding
reverse_index[1] = "<sos>" # start of sequence
reverse_index[2] = "<oov>" # out-of-vocabulary
reverse_index[3] = "<unk>" # unknown

def decode_review(word_ids):
    return " ".join([reverse_index.get(word_id, "<err>") for word_id in word_ids])

maxlen = 90
X_train_trim = keras.preprocessing.sequence.pad_sequences(X_train, maxlen=maxlen)
X_test_trim = keras.preprocessing.sequence.pad_sequences(X_test, maxlen=maxlen)
X_valid_trim = keras.preprocessing.sequence.pad_sequences(X_valid, maxlen=maxlen)

# %% [markdown]
# In this case, we want to use as input/target a one-hot representation for each word. To convert the index representation provided by IMDB dataset loader we use the to_categorical method to transform them in the corresponding one hot representation.

# %%
from tensorflow.keras.utils import to_categorical


X_train_one_hot=to_categorical(X_train_trim)
X_test_one_hot=to_categorical(X_test_trim)
X_valid_one_hot=to_categorical(X_valid_trim)

# %% [markdown]
# Define a linear shallow autoencoder for sequences. The structure will be similar to the model defined in Exercise 5.2, while the used encoding layer is defined by using `tf.keras.layers.SimpleRNN`. Note that it uses linear activations. The decoding layer exploits [tf.keras.layers.TimeDistributed](https://www.tensorflow.org/api_docs/python/tf/keras/layers/TimeDistributed) that allows using the same dense cell at each time step of the sequence.

# %%
inputs = tf.keras.layers.Input(shape=(maxlen, num_words))
encoded = tf.keras.layers.SimpleRNN(50, return_sequences=True, activation='linear')(inputs)

decoded = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(num_words, activation='linear'))(encoded)

sequence_autoencoder = tf.keras.models.Model(inputs, decoded)
encoder = tf.keras.models.Model(inputs, encoded)

sequence_autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=["CategoricalAccuracy"])

sequence_autoencoder.summary()
# Out:
# Model: "model_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_18 (InputLayer)       [(None, 90, 100)]         0
#
#  simple_rnn (SimpleRNN)      (None, 90, 50)            7550
#
#  time_distributed (TimeDistr  (None, 90, 100)          5100
#  ibuted)
#
# =================================================================
# Total params: 12,650
# Trainable params: 12,650
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = sequence_autoencoder.fit(X_train_one_hot, X_train_one_hot, epochs=50, batch_size=128, shuffle=True, validation_data=(X_valid_one_hot, X_valid_one_hot))
# Out:
# Epoch 1/50
# 79/79 [==============================] - 8s 92ms/step - loss: 0.1578 - categorical_accuracy: 0.1777 - val_loss: 0.0762 - val_categorical_accuracy: 0.4502
# Epoch 2/50
# 79/79 [==============================] - 7s 87ms/step - loss: 0.0652 - categorical_accuracy: 0.5046 - val_loss: 0.0594 - val_categorical_accuracy: 0.5277
# Epoch 3/50
# 79/79 [==============================] - 7s 85ms/step - loss: 0.0549 - categorical_accuracy: 0.5489 - val_loss: 0.0511 - val_categorical_accuracy: 0.5642
# Epoch 4/50
# 79/79 [==============================] - 7s 88ms/step - loss: 0.0470 - categorical_accuracy: 0.5958 - val_loss: 0.0443 - val_categorical_accuracy: 0.6024
# Epoch 5/50
# 79/79 [==============================] - 7s 85ms/step - loss: 0.0407 - categorical_accuracy: 0.6317 - val_loss: 0.0390 - val_categorical_accuracy: 0.6471
# Epoch 6/50
# 79/79 [==============================] - 7s 87ms/step - loss: 0.0362 - categorical_accuracy: 0.6598 - val_loss: 0.0347 - val_categorical_accuracy: 0.6686
# Epoch 7/50
# 79/79 [==============================] - 7s 89ms/step - loss: 0.0326 - categorical_accuracy: 0.6935 - val_loss: 0.0312 - val_categorical_accuracy: 0.7148
# Epoch 8/50
# 79/79 [==============================] - 7s 87ms/step - loss: 0.0290 - categorical_accuracy: 0.7219 - val_loss: 0.0281 - val_categorical_accuracy: 0.7474
# Epoch 9/50
# 79/79 [==============================] - 7s 84ms/step - loss: 0.0267 - categorical_accuracy: 0.7562 - val_loss: 0.0261 - val_categorical_accuracy: 0.7639
# Epoch 10/50
# 79/79 [==============================] - 7s 87ms/step - loss: 0.0248 - categorical_accuracy: 0.7814 - val_loss: 0.0242 - val_categorical_accuracy: 0.7920
# Epoch 11/50
# 79/79 [==============================] - 7s 88ms/step - loss: 0.0232 - categorical_accuracy: 0.8084 - val_loss: 0.0229 - val_categorical_accuracy: 0.8198
# Epoch 12/50
# 79/79 [==============================] - 7s 86ms/step - loss: 0.0220 - categorical_accuracy: 0.8304 - val_loss: 0.0217 - val_categorical_accuracy: 0.8360
# Epoch 13/50
# 79/79 [==============================] - 7s 89ms/step - loss: 0.0209 - categorical_accuracy: 0.8491 - val_loss: 0.0207 - val_categorical_accuracy: 0.8544
# Epoch 14/50
# 79/79 [==============================] - 7s 89ms/step - loss: 0.0200 - categorical_accuracy: 0.8632 - val_loss: 0.0200 - val_categorical_accuracy: 0.8682
# Epoch 15/50
# 79/79 [==============================] - 7s 90ms/step - loss: 0.0195 - categorical_accuracy: 0.8774 - val_loss: 0.0197 - val_categorical_accuracy: 0.8858
# Epoch 16/50
# 79/79 [==============================] - 7s 88ms/step - loss: 0.0190 - categorical_accuracy: 0.8867 - val_loss: 0.0190 - val_categorical_accuracy: 0.8876
# Epoch 17/50
# 79/79 [==============================] - 7s 88ms/step - loss: 0.0185 - categorical_accuracy: 0.8926 - val_loss: 0.0185 - val_categorical_accuracy: 0.8938
# Epoch 18/50
# 79/79 [==============================] - 7s 87ms/step - loss: 0.0181 - categorical_accuracy: 0.8988 - val_loss: 0.0181 - val_categorical_accuracy: 0.9004
# Epoch 19/50
# 79/79 [==============================] - 7s 88ms/step - loss: 0.0176 - categorical_accuracy: 0.9035 - val_loss: 0.0177 - val_categorical_accuracy: 0.9033
# Epoch 20/50
# 79/79 [==============================] - 7s 86ms/step - loss: 0.0173 - categorical_accuracy: 0.9064 - val_loss: 0.0174 - val_categorical_accuracy: 0.9063
# Epoch 21/50
# 79/79 [==============================] - 7s 89ms/step - loss: 0.0170 - categorical_accuracy: 0.9090 - val_loss: 0.0170 - val_categorical_accuracy: 0.9092
# Epoch 22/50
# 79/79 [==============================] - 7s 86ms/step - loss: 0.0166 - categorical_accuracy: 0.9120 - val_loss: 0.0167 - val_categorical_accuracy: 0.9114
# Epoch 23/50
# 79/79 [==============================] - 7s 88ms/step - loss: 0.0163 - categorical_accuracy: 0.9135 - val_loss: 0.0164 - val_categorical_accuracy: 0.9126
# Epoch 24/50
# 79/79 [==============================] - 6s 80ms/step - loss: 0.0160 - categorical_accuracy: 0.9146 - val_loss: 0.0162 - val_categorical_accuracy: 0.9136
# Epoch 25/50
# 79/79 [==============================] - 7s 89ms/step - loss: 0.0158 - categorical_accuracy: 0.9155 - val_loss: 0.0160 - val_categorical_accuracy: 0.9144
# Epoch 26/50
# 79/79 [==============================] - 7s 89ms/step - loss: 0.0156 - categorical_accuracy: 0.9162 - val_loss: 0.0158 - val_categorical_accuracy: 0.9150
# Epoch 27/50
# 79/79 [==============================] - 7s 88ms/step - loss: 0.0154 - categorical_accuracy: 0.9168 - val_loss: 0.0156 - val_categorical_accuracy: 0.9156
# Epoch 28/50
# 79/79 [==============================] - 7s 86ms/step - loss: 0.0153 - categorical_accuracy: 0.9173 - val_loss: 0.0154 - val_categorical_accuracy: 0.9161
# Epoch 29/50
# 79/79 [==============================] - 7s 88ms/step - loss: 0.0151 - categorical_accuracy: 0.9176 - val_loss: 0.0152 - val_categorical_accuracy: 0.9165
# Epoch 30/50
# 79/79 [==============================] - 7s 86ms/step - loss: 0.0149 - categorical_accuracy: 0.9180 - val_loss: 0.0151 - val_categorical_accuracy: 0.9169
# Epoch 31/50
# 79/79 [==============================] - 7s 87ms/step - loss: 0.0147 - categorical_accuracy: 0.9183 - val_loss: 0.0149 - val_categorical_accuracy: 0.9174
# Epoch 32/50
# 79/79 [==============================] - 7s 86ms/step - loss: 0.0145 - categorical_accuracy: 0.9195 - val_loss: 0.0145 - val_categorical_accuracy: 0.9194
# Epoch 33/50
# 79/79 [==============================] - 7s 87ms/step - loss: 0.0142 - categorical_accuracy: 0.9203 - val_loss: 0.0143 - val_categorical_accuracy: 0.9196
# Epoch 34/50
# 79/79 [==============================] - 7s 87ms/step - loss: 0.0141 - categorical_accuracy: 0.9207 - val_loss: 0.0142 - val_categorical_accuracy: 0.9199
# Epoch 35/50
# 79/79 [==============================] - 7s 86ms/step - loss: 0.0139 - categorical_accuracy: 0.9209 - val_loss: 0.0140 - val_categorical_accuracy: 0.9202
# Epoch 36/50
# 79/79 [==============================] - 7s 88ms/step - loss: 0.0138 - categorical_accuracy: 0.9211 - val_loss: 0.0139 - val_categorical_accuracy: 0.9204
# Epoch 37/50
# 79/79 [==============================] - 7s 88ms/step - loss: 0.0137 - categorical_accuracy: 0.9213 - val_loss: 0.0138 - val_categorical_accuracy: 0.9205
# Epoch 38/50
# 79/79 [==============================] - 7s 89ms/step - loss: 0.0136 - categorical_accuracy: 0.9214 - val_loss: 0.0137 - val_categorical_accuracy: 0.9206
# Epoch 39/50
# 79/79 [==============================] - 7s 90ms/step - loss: 0.0135 - categorical_accuracy: 0.9215 - val_loss: 0.0136 - val_categorical_accuracy: 0.9207
# Epoch 40/50
# 79/79 [==============================] - 7s 87ms/step - loss: 0.0134 - categorical_accuracy: 0.9216 - val_loss: 0.0135 - val_categorical_accuracy: 0.9208
# Epoch 41/50
# 79/79 [==============================] - 7s 87ms/step - loss: 0.0133 - categorical_accuracy: 0.9216 - val_loss: 0.0134 - val_categorical_accuracy: 0.9209
# Epoch 42/50
# 79/79 [==============================] - 7s 89ms/step - loss: 0.0132 - categorical_accuracy: 0.9217 - val_loss: 0.0133 - val_categorical_accuracy: 0.9209
# Epoch 43/50
# 79/79 [==============================] - 7s 91ms/step - loss: 0.0131 - categorical_accuracy: 0.9217 - val_loss: 0.0132 - val_categorical_accuracy: 0.9210
# Epoch 44/50
# 79/79 [==============================] - 7s 89ms/step - loss: 0.0130 - categorical_accuracy: 0.9217 - val_loss: 0.0131 - val_categorical_accuracy: 0.9211
# Epoch 45/50
# 79/79 [==============================] - 7s 92ms/step - loss: 0.0130 - categorical_accuracy: 0.9218 - val_loss: 0.0131 - val_categorical_accuracy: 0.9211
# Epoch 46/50
# 79/79 [==============================] - 7s 89ms/step - loss: 0.0129 - categorical_accuracy: 0.9218 - val_loss: 0.0130 - val_categorical_accuracy: 0.9211
# Epoch 47/50
# 79/79 [==============================] - 7s 89ms/step - loss: 0.0128 - categorical_accuracy: 0.9218 - val_loss: 0.0129 - val_categorical_accuracy: 0.9211
# Epoch 48/50
# 79/79 [==============================] - 7s 91ms/step - loss: 0.0128 - categorical_accuracy: 0.9219 - val_loss: 0.0129 - val_categorical_accuracy: 0.9211
# Epoch 49/50
# 79/79 [==============================] - 7s 91ms/step - loss: 0.0127 - categorical_accuracy: 0.9219 - val_loss: 0.0128 - val_categorical_accuracy: 0.9212
# Epoch 50/50
# 79/79 [==============================] - 7s 88ms/step - loss: 0.0127 - categorical_accuracy: 0.9219 - val_loss: 0.0128 - val_categorical_accuracy: 0.9212

# %% [markdown]
# Let's plot the accuracy and the loss trends and check the reconstruction capability of the model by plotting the reconstruction of a test sample

# %%
def plot_categorical_accuracy(history):
  plt.figure(figsize=(10,6))
  plt.plot(history.epoch,history.history['categorical_accuracy'])
  plt.plot(history.epoch,history.history['val_categorical_accuracy'])
  plt.title('accuracy')

plot_loss(history)

plot_categorical_accuracy(history)

scores = sequence_autoencoder.evaluate(X_test_one_hot, X_test_one_hot, verbose=2)
print("%s: %.2f%%" % (sequence_autoencoder.metrics_names[1], scores[1]*100))
# Out:
# 40/40 - 1s - loss: 0.0127 - categorical_accuracy: 0.9212 - 540ms/epoch - 13ms/step
# categorical_accuracy: 92.12%

# %%
decoded_text = sequence_autoencoder.predict(X_test_one_hot)
decode_index= np.argmax(decoded_text[500], axis=1)
input_text= np.argmax(X_test_one_hot[500], axis=1)

print(decode_review(input_text))
print(decode_review(decode_index))
# Out:
# than a <oov> <oov> that are <oov> in all of that time but that <oov> the <oov> is <oov> a very <oov> film in just about <oov> <oov> <oov> <oov> as some other <oov> have <oov> out it <oov> like <oov> <oov> of the film are <oov> <oov> there <oov> other <oov> <oov> <oov> are <oov> <oov> in the <oov> <oov> this is a really bad film that <oov> <oov> <oov> than its <oov> of <oov> <oov> i <oov> it <oov> out of <oov> and i <oov> <oov> very <oov>
# a a <oov> <oov> that are <oov> in all of that time but that <oov> the <oov> is <oov> a very <oov> film in just this <oov> <oov> <oov> <oov> as some other <oov> are <oov> who it <oov> like <oov> <oov> of the film are <oov> <oov> there <oov> other <oov> <oov> <oov> are <oov> <oov> in the <oov> <oov> this is a really <oov> film that <oov> <oov> <oov> as its <oov> of <oov> <oov> i <oov> it <oov> this of <oov> and i <oov> <oov> very <oov>

# %% [markdown]
# ##[TO COMPLETE] Exercise 5.7: Non-Linear Autoencoder for sequences
# **[TO COMPLETE]**: Replicate the code of the above exercise, but instead of using a simpleRNN with linear activation do the same  using  non-linear activation functions and using an LSTM layer. Choose the most appropriate non-linear function, and motivate your choice. Then discuss the results in relation to those obtained by the linear autoencoder for sequences.
#
# Hint: using a non-linear function also in the dense layer after the RNN/LSTM one will help to obtain better results. The choice of this function should be based on the type of output data.

# %%
inputs = tf.keras.layers.Input(shape=(maxlen, num_words))
encoded = tf.keras.layers.LSTM(50, return_sequences=True, activation='tanh')(inputs)

decoded = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(num_words, activation='softmax'))(encoded)

sequence_autoencoder = tf.keras.models.Model(inputs, decoded)
encoder = tf.keras.models.Model(inputs, encoded)

sequence_autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=["CategoricalAccuracy"])

sequence_autoencoder.summary()
# Out:
# Model: "model_34"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_25 (InputLayer)       [(None, 90, 100)]         0
#
#  lstm_6 (LSTM)               (None, 90, 50)            30200
#
#  time_distributed_7 (TimeDis  (None, 90, 100)          5100
#  tributed)
#
# =================================================================
# Total params: 35,300
# Trainable params: 35,300
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = sequence_autoencoder.fit(X_train_one_hot, X_train_one_hot, epochs=50, batch_size=128, shuffle=True, validation_data=(X_valid_one_hot, X_valid_one_hot))
# Out:
# Epoch 1/50
# 79/79 [==============================] -
- val_categorical_accuracy: 1.0000
# Epoch 36/50
# 79/79 [==============================] - 12s 149ms/step - loss: 7.1712e-05 - categorical_accuracy: 1.0000 - val_loss: 6.9058e-05 - val_categorical_accuracy: 1.0000
# Epoch 37/50
# 79/79 [==============================] - 12s 147ms/step - loss: 6.6237e-05 - categorical_accuracy: 1.0000 - val_loss: 6.3851e-05 - val_categorical_accuracy: 1.0000
# Epoch 38/50
# 79/79 [==============================] - 12s 150ms/step - loss: 6.1325e-05 - categorical_accuracy: 1.0000 - val_loss: 5.9156e-05 - val_categorical_accuracy: 1.0000
# Epoch 39/50
# 79/79 [==============================] - 12s 146ms/step - loss: 5.6904e-05 - categorical_accuracy: 1.0000 - val_loss: 5.4929e-05 - val_categorical_accuracy: 1.0000
# Epoch 40/50
# 79/79 [==============================] - 11s 144ms/step - loss: 5.2912e-05 - categorical_accuracy: 1.0000 - val_loss: 5.1123e-05 - val_categorical_accuracy: 1.0000
# Epoch 41/50
# 79/79 [==============================] - 12s 148ms/step - loss: 4.9302e-05 - categorical_accuracy: 1.0000 - val_loss: 4.7668e-05 - val_categorical_accuracy: 1.0000
# Epoch 42/50
# 79/79 [==============================] - 12s 149ms/step - loss: 4.6019e-05 - categorical_accuracy: 1.0000 - val_loss: 4.4523e-05 - val_categorical_accuracy: 1.0000
# Epoch 43/50
# 79/79 [==============================] - 12s 150ms/step - loss: 4.3025e-05 - categorical_accuracy: 1.0000 - val_loss: 4.1648e-05 - val_categorical_accuracy: 1.0000
# Epoch 44/50
# 79/79 [==============================] - 11s 145ms/step - loss: 4.0286e-05 - categorical_accuracy: 1.0000 - val_loss: 3.9019e-05 - val_categorical_accuracy: 1.0000
# Epoch 45/50
# 79/79 [==============================] - 12s 149ms/step - loss: 3.7773e-05 - categorical_accuracy: 1.0000 - val_loss: 3.6610e-05 - val_categorical_accuracy: 1.0000
# Epoch 46/50
# 79/79 [==============================] - 12s 146ms/step - loss: 3.5467e-05 - categorical_accuracy: 1.0000 - val_loss: 3.4391e-05 - val_categorical_accuracy: 1.0000
# Epoch 47/50
# 79/79 [==============================] - 11s 145ms/step - loss: 3.3345e-05 - categorical_accuracy: 1.0000 - val_loss: 3.2353e-05 - val_categorical_accuracy: 1.0000
# Epoch 48/50
# 79/79 [==============================] - 12s 149ms/step - loss: 3.1389e-05 - categorical_accuracy: 1.0000 - val_loss: 3.0468e-05 - val_categorical_accuracy: 1.0000
# Epoch 49/50
# 79/79 [==============================] - 12s 147ms/step - loss: 2.9581e-05 - categorical_accuracy: 1.0000 - val_loss: 2.8733e-05 - val_categorical_accuracy: 1.0000
# Epoch 50/50
# 79/79 [==============================] - 11s 146ms/step - loss: 2.7907e-05 - categorical_accuracy: 1.0000 - val_loss: 2.7120e-05 - val_categorical_accuracy: 1.0000

# %%
plot_loss(history)

plot_categorical_accuracy(history)

scores = sequence_autoencoder.evaluate(X_test_one_hot, X_test_one_hot, verbose=2)
print("%s: %.2f%%" % (sequence_autoencoder.metrics_names[1], scores[1]*100))
# Out:
# 40/40 - 1s - loss: 2.7013e-05 - categorical_accuracy: 1.0000 - 890ms/epoch - 22ms/step
# categorical_accuracy: 100.00%

# %% [markdown]
# I tried different combinations of non-linear activation functions. I tried tanh, sigmoid, relu, softmax functions. The best combination is the following one: in the encoding layer I used tanh function which performs better than sigmoid or ReLU, in the decoding layer, since the task is a 2-class classification, I used the softmax function which returns a probabilistic output.
#
# | Autoencoder model | test MSE |
# |:------------:|:---------:|
# |non-linear w/LSTM|100.00%|
# |linear|92.12%|
#
# As shown in the table, the implementation of LSTM in the encoding layer led to better performance since it overcomes the problem of the vanishing of the gradient.
